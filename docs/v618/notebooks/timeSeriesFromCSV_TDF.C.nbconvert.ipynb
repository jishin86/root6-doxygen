// %% [markdown]
// # Time Series From C S V_ T D F
// This macro illustrates the use of the time axis on a TGraph
// with data read from a text file containing the SWAN usage
// statistics during July 2017.
// We exploit the TDataFrame for reading from the file
//
//
//
//
// **Author:**  Danilo Piparo, Olivier Couet
// <i><small>This notebook tutorial was automatically generated with <a href= "https://github.com/root-project/root/blob/master/documentation/doxygen/converttonotebook.py">ROOTBOOK-izer</a> from the macro found in the ROOT repository  on Thursday, August 29, 2019 at 01:50 AM.</small></i>

// %% [markdown]
// Open the data file. this csv contains the usage statistics of a cern it
//  service, SWAN, during two weeks. We would like to plot this data with
//  ROOT to draw some conclusions from it.

// %%
TString dir = gROOT->GetTutorialDir();
dir.Append("/graphs/");
dir.ReplaceAll("/./", "/");

// %% [markdown]
// Read the data from the file using tdataframe. we do not have headers and
//  we would like the delimiter to be a space

// %%
auto tdf = ROOT::RDF::MakeCsvDataFrame(Form("%sSWAN2017.dat", dir.Data()), false, ' ');

// %% [markdown]
// We now prepare the graph input

// %%
auto d = tdf.Define("TimeStamp", "auto s = string(Col0) + ' ' +  Col1; return (float) TDatime(s.c_str()).Convert();")
            .Define("Value", "(float)Col2");
auto timeStamps = d.Take<float>("TimeStamp");
auto values = d.Take<float>("Value");

// %% [markdown]
// Create the time graph

// %%
auto g = new TGraph(values->size(), timeStamps->data(), values->data());
g->SetTitle("SWAN Users during July 2017;Time;Number of Sessions");

// %% [markdown]
// Draw the graph

// %%
auto c = new TCanvas("c", "c", 950, 500);
c->SetLeftMargin(0.07);
c->SetRightMargin(0.04);
c->SetGrid();
g->SetLineWidth(3);
g->SetLineColor(kBlue);
g->Draw("al");
g->GetYaxis()->CenterTitle();

// %% [markdown]
// Make the x axis labelled with time.

// %%
auto xaxis = g->GetXaxis();
xaxis->SetTimeDisplay(1);
xaxis->CenterTitle();
xaxis->SetTimeFormat("%a %d");
xaxis->SetTimeOffset(0);
xaxis->SetNdivisions(-219);
xaxis->SetLimits(TDatime(2017, 7, 3, 0, 0, 0).Convert(), TDatime(2017, 7, 22, 0, 0, 0).Convert());
xaxis->SetLabelSize(0.025);
xaxis->CenterLabels();

// %% [markdown]
// Draw all canvases

// %%
%jsroot on
gROOT->GetListOfCanvases()->Draw()
// Out:
// <div id="root_plot_1"
//      style="width: 946px; height: 472px">
// </div>
//
// <script>
//  requirejs.config({
//      paths: {
//        'JSRootCore' : 'https://root.cern.ch/js/notebook//scripts/JSRootCore',
//      }
//    });
//  require(['JSRootCore'],
//      function(Core) {
//        var obj = Core.JSONR_unref({"_typename":"TCanvas","fUniqueID":0,"fBits":53673992,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fLeftMargin":0.07,"fRightMargin":0.04,"fBottomMargin":0.1,"fTopMargin":0.1,"fXfile":2,"fYfile":2,"fAfile":1,"fXstat":0.99,"fYstat":0.99,"fAstat":2,"fFrameFillColor":0,"fFrameLineColor":1,"fFrameFillStyle":1001,"fFrameLineStyle":1,"fFrameLineWidth":1,"fFrameBorderSize":1,"fFrameBorderMode":0,"fX1":1498910885.39063,"fY1":-28.7472947588037,"fX2":1500755379.77482,"fY2":348.725630330093,"fXtoAbsPixelk":-768757.936942347,"fXtoPixelk":-768757.936942347,"fXtoPixel":5.12877679710759e-4,"fYtoAbsPixelk":436.053834458952,"fYtoPixelk":436.053834458952,"fYtoPixel":-1.25042080803237,"fUtoAbsPixelk":5e-5,"fUtoPixelk":5e-5,"fUtoPixel":946,"fVtoAbsPixelk":472.00005,"fVtoPixelk":472,"fVtoPixel":-472,"fAbsPixeltoXk":1498910885.39063,"fPixeltoXk":1498910885.39063,"fPixeltoX":1949.78264712935,"fAbsPixeltoYk":348.725630330093,"fPixeltoYk":-28.7472947588037,"fPixeltoY":-0.799730773493425,"fXlowNDC":0,"fYlowNDC":0,"fXUpNDC":0,"fYUpNDC":0,"fWNDC":1,"fHNDC":1,"fAbsXlowNDC":0,"fAbsYlowNDC":0,"fAbsWNDC":1,"fAbsHNDC":1,"fUxmin":1499040000,"fUymin":9,"fUxmax":1500681600,"fUymax":310.978335571289,"fTheta":30,"fPhi":30,"fAspectRatio":0,"fNumber":0,"fTickx":0,"fTicky":0,"fLogx":0,"fLogy":0,"fLogz":0,"fPadPaint":0,"fCrosshair":0,"fCrosshairPos":0,"fBorderSize":2,"fBorderMode":0,"fModified":false,"fGridx":true,"fGridy":true,"fAbsCoord":false,"fEditable":true,"fFixedAspectRatio":false,"fPrimitives":{"_typename":"TList","name":"TList","arr":[{"_typename":"TFrame","fUniqueID":0,"fBits":50331656,"fLineColor":1,"fLineStyle":1,"fLineWidth":1,"fFillColor":0,"fFillStyle":1001,"fX1":1499040000,"fY1":9,"fX2":1500681600,"fY2":310.978335571289,"fBorderSize":1,"fBorderMode":0},{"_typename":"TGraph","fUniqueID":0,"fBits":50332680,"fName":"Graph","fTitle":"SWAN Users during July 2017","fLineColor":600,"fLineStyle":1,"fLineWidth":3,"fFillColor":0,"fFillStyle":1000,"fMarkerColor":1,"fMarkerStyle":1,"fMarkerSize":1,"fNpoints":456,"fX":[1499043584,1499047168,1499050752,1499054336,1499058048,1499061632,1499065216,1499068800,1499072384,1499075968,1499079552,1499083264,1499086848,1499090432,1499094016,1499097600,1499101184,1499104768,1499108352,1499111936,1499115648,1499119232,1499122816,1499126400,1499129984,1499133568,1499137152,1499140864,1499144448,1499148032,1499151616,1499155200,1499158784,1499162368,1499165952,1499169536,1499173248,1499176832,1499180416,1499184000,1499187584,1499191168,1499194752,1499198464,1499202048,1499205632,1499209216,1499212800,1499216384,1499219968,1499223552,1499227136,1499230848,1499234432,1499238016,1499241600,1499245184,1499248768,1499252352,1499256064,1499259648,1499263232,1499266816,1499270400,1499273984,1499277568,1499281152,1499284736,1499288448,1499292032,1499295616,1499299200,1499302784,1499306368,1499309952,1499313664,1499317248,1499320832,1499324416,1499328000,1499331584,1499335168,1499338752,1499342336,1499346048,1499349632,1499353216,1499356800,1499360384,1499363968,1499367552,1499371264,1499374848,1499378432,1499382016,1499385600,1499389184,1499392768,1499396352,1499399936,1499403648,1499407232,1499410816,1499414400,1499417984,1499421568,1499425152,1499428864,1499432448,1499436032,1499439616,1499443200,1499446784,1499450368,1499453952,1499457536,1499461248,1499464832,1499468416,1499472000,1499475584,1499479168,1499482752,1499486464,1499490048,1499493632,1499497216,1499500800,1499504384,1499507968,1499511552,1499515136,1499518848,1499522432,1499526016,1499529600,1499533184,1499536768,1499540352,1499544064,1499547648,1499551232,1499554816,1499558400,1499561984,1499565568,1499569152,1499572736,1499576448,1499580032,1499583616,1499587200,1499590784,1499594368,1499597952,1499601664,1499605248,1499608832,1499612416,1499616000,1499619584,1499623168,1499626752,1499630336,1499634048,1499637632,1499641216,1499644800,1499648384,1499651968,1499655552,1499659264,1499662848,1499666432,149 ...
